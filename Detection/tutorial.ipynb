# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 5.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
##Remember to change the directory in dataset.yaml file
# !unzip /content/drive/MyDrive/bdd_in_YOLOV5.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: bdd_in_YOLOV5/labels/train/36a3a483-0c50efe8.txt
#   inflating: bdd_in_YOLOV5/labels/train/07baa41b-e992e1fa.txt
#   inflating: bdd_in_YOLOV5/labels/train/11ecaf4a-8586f43d.txt
#   inflating: bdd_in_YOLOV5/labels/train/73990194-fd083072.txt
#   inflating: bdd_in_YOLOV5/labels/train/5823b731-298af202.txt
#   inflating: bdd_in_YOLOV5/labels/train/731520a9-330da0fe.txt
#   inflating: bdd_in_YOLOV5/labels/train/11513e3d-864faa0c.txt
#   inflating: bdd_in_YOLOV5/labels/train/5441041a-8f6afb64.txt
#   inflating: bdd_in_YOLOV5/labels/train/8d638e0a-bf784511.txt
#   inflating: bdd_in_YOLOV5/labels/train/17d449e4-410ad359.txt
#   inflating: bdd_in_YOLOV5/labels/train/0ed6dbb4-dee41a44.txt
#   inflating: bdd_in_YOLOV5/labels/train/60c3ab38-4b851668.txt
#   inflating: bdd_in_YOLOV5/labels/train/5d0d9901-e14bd79c.txt
#   inflating: bdd_in_YOLOV5/labels/train/8bee15cc-f2e6f573.txt
# ...

# %%
# !unzip /content/drive/MyDrive/cs766.zip
# Out:
# Archive:  /content/drive/MyDrive/cs766.zip
# replace cs766/train.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# !python /content/cs766/train.py
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !unzip /content/drive/MyDrive/100k_images_test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: bdd100k/images/100k/test/e01a2b3d-c114c723.jpg
#   inflating: bdd100k/images/100k/test/e9596b55-1fe28183.jpg
#   inflating: bdd100k/images/100k/test/f763f5b4-9f4efbdf.jpg
#   inflating: bdd100k/images/100k/test/cc2fa3e3-f8d2cf56.jpg
#   inflating: bdd100k/images/100k/test/d03f6523-bf0cda40.jpg
#   inflating: bdd100k/images/100k/test/d3cb9538-90091599.jpg
#   inflating: bdd100k/images/100k/test/d2fadc0f-d5bf298c.jpg
#   inflating: bdd100k/images/100k/test/f88519f9-3dabfe5e.jpg
#   inflating: bdd100k/images/100k/test/f849ef52-4bdd7857.jpg
#   inflating: bdd100k/images/100k/test/de8413d2-673c5210.jpg
#   inflating: bdd100k/images/100k/test/e9364c60-204c8dae.jpg
#   inflating: bdd100k/images/100k/test/dd148352-7c634362.jpg
#   inflating: bdd100k/images/100k/test/f1a2704e-e770c700.jpg
#   inflating: bdd100k/images/100k/test/f6310e2a-fdf0adab.jpg
#   inflating: bdd100k/images/100k/test/e91ccb05-d85f3105.jpg
# ...

# %%
# !yolo predict model=/content/runs/detect/train/weights/best.pt source=/content/bdd100k/images/100k/test/*.jpg
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/20000 /content/bdd100k/images/100k/test/cabc30fc-e7726578.jpg: 384x640 3 traffic signs, 3 cars, 1 pedestrian, 92.4ms
# image 2/20000 /content/bdd100k/images/100k/test/cabc30fc-eb673c5a.jpg: 384x640 2 traffic signs, 8 cars, 7.8ms
# image 3/20000 /content/bdd100k/images/100k/test/cabc30fc-fd79926f.jpg: 384x640 4 cars, 5 pedestrians, 1 truck, 1 rider, 7.8ms
# image 4/20000 /content/bdd100k/images/100k/test/cabc9045-1b8282ba.jpg: 384x640 3 traffic lights, 1 traffic sign, 20 cars, 7.0ms
# image 5/20000 /content/bdd100k/images/100k/test/cabc9045-581f64de.jpg: 384x640 1 traffic light, 3 traffic signs, 7 cars, 7.2ms
# image 6/20000 /content/bdd100k/images/100k/test/cabc9045-5a50690f.jpg: 384x640 5 traffic lights, 5 cars, 6.9ms
# ...

# %%
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/e0003b8b-abd61c6f.jpg (deflated 9%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 6%)
#   adding: content/runs/detect/train/results.csv (deflated 80%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 16%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/R_curve.png (deflated 7%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 10%)
#   adding: content/runs/detect/train/labels.jpg (deflated 32%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 7%)
# ...
